# %%
! pip install python-google-places
# Out:
# Requirement already satisfied: python-google-places in /usr/local/lib/python3.7/dist-packages (1.4.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from python-google-places) (1.15.0)

# %%
import pandas as pd, numpy as np
import requests
import json
import time
final_data = []
# Parameters
coordinates = ['-8.705833, 115.261377']
keywords = ['restaurant']

from googleplaces import GooglePlaces, types, lang

API_KEY = 'AIzaSyD1qkItnF9DfuqEyaA6NIyfB11W2G2udyI'


query_result = google_places.nearby_search(location='Bangladesh', keyword='Restaurants', lat_lng={'lat': 23.7104000, 'lng': 90.4074400},
    radius=50000, types=[types.TYPE_RESTAURANT])


if query_result.has_attributions:
    print (query_result.html_attributions)


for place in query_result.places:
    name = place.name
    place_id = place.place_id
   
    rating = place.rating
    types = place.types
    location=place.geo_location
    details= place.get_details
    
    
    #print (place.rating) 
     # Returned places from a query are place summaries.
    #print (place.name)
    #print (place.geo_location)
    #print (place.place_id)

    # The following method has to make a further API call.
    place.get_details()
    add={}
    add=place.geo_location
    lat=add["lat"]
    lng=add["lng"]
    g_map=place.url
    #print(lat)
    #print(lng)
    # Referencing any of the attributes below, prior to making a call to
    # get_details() will raise a googleplaces.GooglePlacesAttributeError.
    #print (place.details) # A dict matching the JSON response from Google.
    #print (place.url)
    
    data = [name, place_id,lat,lng, rating, types,g_map]
    final_data.append(data)
labels = ['Place Name','Place ID','Latitude','Longitude','Rating','Types',"Google Map"]
export_dataframe_1_medium = pd.DataFrame.from_records(final_data, columns=labels)
export_dataframe_1_medium.to_csv('my.csv')

# %%
df = pd.read_csv("/content/my.csv",sep=",")
df
# Out:
#     Unnamed: 0  ...                                         Google Map
# 0            0  ...  https://maps.google.com/?cid=11163414373424187692
# 1            1  ...  https://maps.google.com/?cid=10316977154517893672
# 2            2  ...  https://maps.google.com/?cid=17808475715761445555
# 3            3  ...  https://maps.google.com/?cid=17993933856225006749
# 4            4  ...  https://maps.google.com/?cid=10750934450470615166
# 5            5  ...   https://maps.google.com/?cid=5427969390580530706
# 6            6  ...  https://maps.google.com/?cid=16451020312633094552
# 7            7  ...  https://maps.google.com/?cid=18294427304712127269
# 8            8  ...   https://maps.google.com/?cid=1062660003999789894
# 9            9  ...   https://maps.google.com/?cid=4591474725197078207
# 10          10  ...  https://maps.google.com/?cid=17499464859844770652
# 11          11  ...  https://maps.google.com/?cid=10487020934740572523
# 12          12  ...   https://maps.google.com/?cid=4601829421797228195
# 13          13  ...   https://maps.google.com/?cid=8413998579388290230
# 14          14  ...   https://maps.google.com/?cid=8573050887692218340
# 15          15  ...  https://maps.google.com/?cid=10945445866165755509
# 16          16  ...   https://maps.google.com/?cid=6109173481649723181
# 17          17  ...  https://maps.google.com/?cid=10972482071458312969
# 18          18  ...   https://maps.google.com/?cid=2418415669973033145
# 19          19  ...   https://maps.google.com/?cid=7512034983717744471
#
# [20 rows x 8 columns]
